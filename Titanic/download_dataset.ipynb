# %%
import kaggle

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api = KaggleApi()
api.authenticate()

# %%
competitions = api.competitions_list(search='cat',category="playground")

for comp in competitions:  
    print(comp.ref,comp.reward,comp.userRank,sep=',')
# Out:
# cat-in-the-dat,Swag,0
# cat-in-the-dat-ii,Swag,0
# dogs-vs-cats-redux-kernels-edition,Knowledge,0
# dogs-vs-cats,Swag,0

# %%
api.competition_download_files('titanic')
# !unzip \*.zip  && rm *.zip
# Out:
# 'unzip' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.
